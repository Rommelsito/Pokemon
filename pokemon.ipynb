# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Inicializamos Dataset

# %%
df_pokemon = pd.read_csv("Pokemon.csv")
df_pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ##### Verificamos Datos

# %%
#Informacios de los Datos de cada columna
df_pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
#Descripciones estadisticas
df_pokemon.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
#Forma del dataframe
df_pokemon.shape
# Out:
# (800, 13)

# %% [markdown]
# #### Tratamiento de los Datos

# %%
df_1 = df_pokemon.copy()
df_1.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#Renombrando columna con el metodo rename
df_1 = df_1.rename(columns = ({"#":"ID"}))
df_1.head(8)
# Out:
#    ID                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0   1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1   2                    Ivysaur  Grass  Poison    405  60      62       63
# 2   3                   Venusaur  Grass  Poison    525  80      82       83
# 3   3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4   4                 Charmander   Fire     NaN    309  39      52       43
# 5   5                 Charmeleon   Fire     NaN    405  58      64       58
# 6   6                  Charizard   Fire  Flying    534  78      84       78
# 7   6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# ...

# %%
df_1["ID"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 800 entries, 0 to 799
# Series name: ID
# Non-Null Count  Dtype
# --------------  -----
# 800 non-null    int64
# dtypes: int64(1)
# memory usage: 6.4 KB

# %%
df_1.groupby("Type 1")["Type 2"].describe()
# Out:
#          count unique       top freq
# Type 1
# Bug         52     11    Flying   14
# Dark        21      8    Flying    5
# Dragon      21      7    Flying    6
# Electric    17     10    Flying    5
# Fairy        2      1    Flying    2
# Fighting     7      4   Psychic    3
# Fire        24      9  Fighting    7
# Flying       2      1    Dragon    2
# Ghost       22      6     Grass   10
# Grass       37     10    Poison   15
# Ground      19      9    Flying    4
# Ice         11      5    Ground    3
# Normal      37      7    Flying   24
# Poison      13      7    Flying    3
# Psychic     19      7     Fairy    6
# Rock        35     12    Ground    6
# Steel       22      8   Psychic    7
# Water       53     14    Ground   10

# %% [markdown]
# #### Tratamiento de la columna [Type2]

# %%
df_2 = df_1.copy()
df_2
# Out:
#       ID                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df_2_notnull = df_2.dropna()
df_2_notnull
# Out:
#       ID                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6      6              Charizard     Fire  Flying    534  78      84       78
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df_2["Name"].nunique()
# Out:
# 800

# %%
df_2["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df_2_null = df_2[df_2["Type 2"].isnull()]
df_2_null
# Out:
#       ID        Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 4      4  Charmander    Fire    NaN    309   39      52       43       60
# 5      5  Charmeleon    Fire    NaN    405   58      64       58       80
# 9      7    Squirtle   Water    NaN    314   44      48       65       50
# 10     8   Wartortle   Water    NaN    405   59      63       80       65
# 11     9   Blastoise   Water    NaN    530   79      83      100       85
# ..   ...         ...     ...    ...    ...  ...     ...      ...      ...
# 775  705     Sliggoo  Dragon    NaN    452   68      75       53       83
# 776  706      Goodra  Dragon    NaN    600   90     100       70      110
# 788  712    Bergmite     Ice    NaN    304   55      69       85       32
# 789  713     Avalugg     Ice    NaN    514   95     117      184       44
# 792  716     Xerneas   Fairy    NaN    680  126     131       95      131
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df_2_null["Type 1"].unique()
# Out:
# array(['Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric', 'Ground',
#        'Fairy', 'Fighting', 'Psychic', 'Grass', 'Dragon', 'Rock', 'Dark',
#        'Ghost', 'Steel', 'Ice', 'Flying'], dtype=object)

# %%
df_2_null.groupby("Type 1")['Type 2'].size().reset_index()
# Out:
#       Type 1  Type 2
# 0        Bug      17
# 1       Dark      10
# 2     Dragon      11
# 3   Electric      27
# 4      Fairy      15
# 5   Fighting      20
# 6       Fire      28
# 7     Flying       2
# 8      Ghost      10
# 9      Grass      33
# 10    Ground      13
# 11       Ice      13
# 12    Normal      61
# 13    Poison      15
# 14   Psychic      38
# 15      Rock       9
# 16     Steel       5
# 17     Water      59

# %% [markdown]
# ##### Trabajo de datos nulos en type 2

# %%
df_3 = df_2_null.copy()
df_3
# Out:
#       ID        Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 4      4  Charmander    Fire    NaN    309   39      52       43       60
# 5      5  Charmeleon    Fire    NaN    405   58      64       58       80
# 9      7    Squirtle   Water    NaN    314   44      48       65       50
# 10     8   Wartortle   Water    NaN    405   59      63       80       65
# 11     9   Blastoise   Water    NaN    530   79      83      100       85
# ..   ...         ...     ...    ...    ...  ...     ...      ...      ...
# 775  705     Sliggoo  Dragon    NaN    452   68      75       53       83
# 776  706      Goodra  Dragon    NaN    600   90     100       70      110
# 788  712    Bergmite     Ice    NaN    304   55      69       85       32
# 789  713     Avalugg     Ice    NaN    514   95     117      184       44
# 792  716     Xerneas   Fairy    NaN    680  126     131       95      131
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df_3[df_3["Type 1"] == "Fire"].shape
# Out:
# (28, 13)

# %%
df_1.groupby("Type 1")["Type 2"].describe()
# Out:
#          count unique       top freq
# Type 1
# Bug         52     11    Flying   14
# Dark        21      8    Flying    5
# Dragon      21      7    Flying    6
# Electric    17     10    Flying    5
# Fairy        2      1    Flying    2
# Fighting     7      4   Psychic    3
# Fire        24      9  Fighting    7
# Flying       2      1    Dragon    2
# Ghost       22      6     Grass   10
# Grass       37     10    Poison   15
# Ground      19      9    Flying    4
# Ice         11      5    Ground    3
# Normal      37      7    Flying   24
# Poison      13      7    Flying    3
# Psychic     19      7     Fairy    6
# Rock        35     12    Ground    6
# Steel       22      8   Psychic    7
# Water       53     14    Ground   10

# %% [markdown]
# #### Rellenando Datos Dulos por type 1

# %%
df_3_Fire = df_3[df_3["Type 1"] == "Fire"].fillna("Fighting")
df_3_Bug = df_3[df_3["Type 1"] == "Bug"].fillna("Flying")
df_3_Dark = df_3[df_3["Type 1"] == "Dark"].fillna("Flying")
df_3_Dragon = df_3[df_3["Type 1"] == "Dragon"].fillna("Flying")
df_3_Electric = df_3[df_3["Type 1"] == "Electric"].fillna("Flying")
df_3_Fairy = df_3[df_3["Type 1"] == "Fairy"].fillna("Flying")

# %%
df_3_Fighting = df_3[df_3["Type 1"] == "Fighting"].fillna("Psychic")
df_3_Flying = df_3[df_3["Type 1"] == "Flying"].fillna("Dragon")
df_3_Ghost = df_3[df_3["Type 1"] == "Ghost"].fillna("Grass")
df_3_Grass = df_3[df_3["Type 1"] == "Grass"].fillna("Poison")
df_3_Ground = df_3[df_3["Type 1"] == "Ground"].fillna("Flying")

# %%
df_3_Ice = df_3[df_3["Type 1"] == "Ice"].fillna("Ground")
df_3_Normal = df_3[df_3["Type 1"] == "Normal"].fillna("Flying")
df_3_Poison = df_3[df_3["Type 1"] == "Poison"].fillna("Flying")
df_3_Psychic = df_3[df_3["Type 1"] == "Psychic"].fillna("Fairy")
df_3_Rock = df_3[df_3["Type 1"] == "Rock"].fillna("Ground")
df_3_Steel = df_3[df_3["Type 1"] == "Steel"].fillna("Psychic")
df_3_Water = df_3[df_3["Type 1"] == "Water"].fillna("Ground")

# %% [markdown]
# ##### Concatenando

# %%
df_concat = pd.concat([

    df_3_Fire,
    df_3_Grass,
    df_3_Bug,
    df_3_Dark,
    df_3_Dragon,
    df_3_Electric,
    df_3_Fairy,
    df_3_Fighting,
    df_3_Flying,
    df_3_Ghost,
    df_3_Ground,
    df_3_Ice,
    df_3_Normal,
    df_3_Poison,
    df_3_Psychic,
    df_3_Rock,
    df_3_Steel,
    df_3_Water,

])

# %%
df_concat
# Out:
#       ID        Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 4      4  Charmander   Fire  Fighting    309   39      52       43       60
# 5      5  Charmeleon   Fire  Fighting    405   58      64       58       80
# 42    37      Vulpix   Fire  Fighting    299   38      41       40       50
# 43    38   Ninetales   Fire  Fighting    505   73      76       75       81
# 63    58   Growlithe   Fire  Fighting    350   55      70       45       70
# ..   ...         ...    ...       ...    ...  ...     ...      ...      ...
# 655  594   Alomomola  Water    Ground    470  165      75       80       40
# 724  656     Froakie  Water    Ground    314   41      56       40       62
# 725  657   Frogadier  Water    Ground    405   54      63       52       83
# 762  692   Clauncher  Water    Ground    330   50      53       62       58
# 763  693   Clawitzer  Water    Ground    500   71      73       88      120
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df_total = pd.concat([

    df_2_notnull,
    df_concat,

]).sort_index() #Metodo para ordenar los indices e menor a mayor

# %%
df_total
# Out:
#       ID                   Name   Type 1    Type 2  Total  HP  Attack  \
# 0      1              Bulbasaur    Grass    Poison    318  45      49
# 1      2                Ivysaur    Grass    Poison    405  60      62
# 2      3               Venusaur    Grass    Poison    525  80      82
# 3      3  VenusaurMega Venusaur    Grass    Poison    625  80     100
# 4      4             Charmander     Fire  Fighting    309  39      52
# ..   ...                    ...      ...       ...    ...  ..     ...
# 795  719                Diancie     Rock     Fairy    600  50     100
# 796  719    DiancieMega Diancie     Rock     Fairy    700  50     160
# 797  720    HoopaHoopa Confined  Psychic     Ghost    600  80     110
# 798  720     HoopaHoopa Unbound  Psychic      Dark    680  80     160
# 799  721              Volcanion     Fire     Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49       65       65     45           1      False
# ...

# %% [markdown]
# ##### Creando archivo CSV

# %%
df_total.to_csv("df_clean.csv", index = False)
